# %% [markdown]
# <a href="https://colab.research.google.com/github/Fiarma5233/Data-Science/blob/master/Data_Input_Output_With_Excel_File.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# un fichier excel est un dictionnaire dont les cles sont les noms des feuillets et les valeurs sont les dataframes correspondants

# %%
# on precise en parametre le nom du feuillet qu'on veut lire
excel = pd.read_excel('/content/drive/MyDrive/MasterClass_DataScience_Machine_Learning_Notebooks_et_Datasets/03-Pandas/Datasets/my_excel_file.xlsx', sheet_name='First_Sheet')

# %%
excel
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
# Pour un fichier excel tres volume et qu'on ne connait pas le nombre de feuillets qu'il ya on peut le chercher
 # On mettre dans les parametres, sheet_name=None
excel = pd.read_excel('/content/drive/MyDrive/MasterClass_DataScience_Machine_Learning_Notebooks_et_Datasets/03-Pandas/Datasets/my_excel_file.xlsx', sheet_name=None)

# %%
# on verifie qu'il s'agit d'un objet de type dictionnaire
type(excel)
# Out:
# dict

# %%
# on affiche les cles du dictionnaire qui sont les noms des feuillets de notre fichier excel
excel.keys()
# Out:
# dict_keys(['First_Sheet'])

# %%
# on peut recuperer les valeurs d'un feuillet en passant le nom du feuillet= cle
excel['First_Sheet']
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
# Ecrire dans un fichier excel
df = excel['First_Sheet']
df.to_excel('mon_fichier_excel.xlsx', sheet_name='First_Sheet',index=False)
