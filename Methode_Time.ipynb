# %% [markdown]
# <a href="https://colab.research.google.com/github/Fiarma5233/Data-Science/blob/master/Methode_Time.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Manipulation des donnees de series temporelles

# %%
import numpy as np
import pandas as pd
import datetime as datetime

# %%
my_series= pd.Series(['Feb 3, 2022', '2001-12-31', None])

# %%
my_series
# Out:
# 0    Feb 3, 2022
# 1     2001-12-31
# 2           None
# dtype: object

# %%
pd.to_datetime(my_series, format='mixed') # Pour convertir en date
# Out:
# 0   2022-02-03
# 1   2001-12-31
# 2          NaT
# dtype: datetime64[ns]

# %%
#Il ya deux formats de date:
      #Le format europeen : annee-mois-jour
obvious_euro_date = "31-12-2001" # version francaise comme on l'ecris chez nous
pd.to_datetime(obvious_euro_date) # conversion en date qui par defaut est au format americain


#Le format americain : annee-jour-mois
euro_date = "10-09-2009"
pd.to_datetime(euro_date)


# Pour convertir une date dans le format europeen , on specifie en parametre : dayfirst=True
pd.to_datetime(euro_date, dayfirst=True)
# Out:
# <ipython-input-12-df151cdc769d>:4: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   pd.to_datetime(obvious_euro_date) # conversion en date qui par defaut est au format americain
# Timestamp('2009-09-10 00:00:00')

# %%
# specifier le format de date d'entree
date_bizarre = '23--Feb--2024'
pd.to_datetime(date_bizarre, format='%d--%b--%Y')
# Out:
# Timestamp('2024-02-23 00:00:00')

# %%
sales = pd.read_csv('/content/drive/MyDrive/MasterClass_DataScience_Machine_Learning_Notebooks_et_Datasets/03-Pandas/Datasets/RetailSales_BeerWineLiquor.csv')

# %%
sales
# Out:
#            DATE  MRTSSM4453USN
# 0    1992-01-01           1509
# 1    1992-02-01           1541
# 2    1992-03-01           1597
# 3    1992-04-01           1675
# 4    1992-05-01           1822
# ..          ...            ...
# 335  2019-12-01           6630
# 336  2020-01-01           4388
# 337  2020-02-01           4533
# 338  2020-03-01           5562
# 339  2020-04-01           5207
#
# [340 rows x 2 columns]

# %%
# Lire dans le fichier csv en analysant directement la date,
# Pour le faire on ajoute dans les paramettee de la methode read_csv , parse_dates=[index de la colonne contenant la date]
sales = pd.read_csv('/content/drive/MyDrive/MasterClass_DataScience_Machine_Learning_Notebooks_et_Datasets/03-Pandas/Datasets/RetailSales_BeerWineLiquor.csv',parse_dates=[0])
sales
# Out:
#           DATE  MRTSSM4453USN
# 0   1992-01-01           1509
# 1   1992-02-01           1541
# 2   1992-03-01           1597
# 3   1992-04-01           1675
# 4   1992-05-01           1822
# ..         ...            ...
# 335 2019-12-01           6630
# 336 2020-01-01           4388
# 337 2020-02-01           4533
# 338 2020-03-01           5562
# 339 2020-04-01           5207
#
# [340 rows x 2 columns]

# %%
# reechantillonnage sur les donnees de series temporelles
    # on fixe l'index qui prendra la colonne de la date
sales =sales.set_index('DATE')
sales
# Out:
#             MRTSSM4453USN
# DATE
# 1992-01-01           1509
# 1992-02-01           1541
# 1992-03-01           1597
# 1992-04-01           1675
# 1992-05-01           1822
# ...                   ...
# 2019-12-01           6630
# 2020-01-01           4388
# 2020-02-01           4533
# 2020-03-01           5562
# 2020-04-01           5207
#
# [340 rows x 1 columns]

# %%
#Reechantillons en calculant la moyenne  en chaque fin d'annee
sales.resample(rule='A').mean()
# Out:
#             MRTSSM4453USN
# DATE
# 1992-12-31    1807.250000
# 1993-12-31    1794.833333
# 1994-12-31    1841.750000
# 1995-12-31    1833.916667
# 1996-12-31    1929.750000
# 1997-12-31    2006.750000
# 1998-12-31    2115.166667
# 1999-12-31    2206.333333
# 2000-12-31    2375.583333
# 2001-12-31    2468.416667
# 2002-12-31    2491.166667
# 2003-12-31    2539.083333
# 2004-12-31    2682.416667
# 2005-12-31    2797.250000
# 2006-12-31    3001.333333
# 2007-12-31    3177.333333
# 2008-12-31    3292.000000
# 2009-12-31    3353.750000
# 2010-12-31    3450.083333
# 2011-12-31    3532.666667
# 2012-12-31    3697.083333
# 2013-12-31    3839.666667
# 2014-12-31    4023.833333
# 2015-12-31    4212.500000
# 2016-12-31    4434.416667
# 2017-12-31    4602.666667
# 2018-12-31    4830.666667
# 2019-12-31    4972.750000
# 2020-12-31    4922.500000

# %%
sales = pd.read_csv('/content/drive/MyDrive/MasterClass_DataScience_Machine_Learning_Notebooks_et_Datasets/03-Pandas/Datasets/RetailSales_BeerWineLiquor.csv',parse_dates=[0])

sales['DATE'].dt.year
# Out:
# 0      1992
# 1      1992
# 2      1992
# 3      1992
# 4      1992
#        ...
# 335    2019
# 336    2020
# 337    2020
# 338    2020
# 339    2020
# Name: DATE, Length: 340, dtype: int32
